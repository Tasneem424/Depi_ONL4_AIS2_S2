# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

data=pd.read_csv('Social_Network_Ads.csv')
data.head()
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510    Male   19            19000          0
# 1  15810944    Male   35            20000          0
# 2  15668575  Female   26            43000          0
# 3  15603246  Female   27            57000          0
# 4  15804002    Male   19            76000          0

# %%
x=data.iloc[:,[2,3]]
y=data.iloc[:,4]

# %%
from sklearn.model_selection import train_test_split

x_train,x_test, y_train, y_test= train_test_split(x,y,test_size=0.2,random_state=20)

# %%
from sklearn.preprocessing import StandardScaler
sc_x=StandardScaler()
x_train=sc_x.fit_transform(x_train)
x_test=sc_x.transform(x_test)

# %%
from sklearn.linear_model import LogisticRegression
classifier=LogisticRegression()
classifier.fit(x_train,y_train)
y_pred=classifier.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix,recall_score,accuracy_score,precision_score,f1_score

# %%
cm=confusion_matrix(y_test,y_pred)
cm
# Out:
# array([[46,  3],
#        [10, 21]])

# %%
tp,fp,fn,tn=cm.ravel()

# %%
def accuracy_sc(tp,fp,fn,tn):
     return (tp+tn)/(tp,fp,fn,tn)

# %%
accuracy_sc(tp,fp,fn,tn)
# Out:
# array([ 1.45652174, 22.33333333,  6.7       ,  3.19047619])

# %%
acc=accuracy_score(y_test,y_pred)
recall=recall_score(y_test,y_pred)
precision=precision_score(y_train,y_pred)
f1_score=f1_score(y_train,y_pred)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 3
#       1 acc=accuracy_score(y_test,y_pred)
#       2 recall=recall_score(y_test,y_pred)
# ----> 3 precision=precision_score(y_train,y_pred)
#       4 f1_score=f1_score(y_train,y_pred)
#
# File c:\Users\tasne\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\_param_validation.py:218, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     212 try:
#     213     with config_context(
#     214         skip_parameter_validation=(
#     215             prefer_skip_nested_validation or global_skip_validation
#     216         )
#     217     ):
# --> 218         return func(*args, **kwargs)
#     219 except InvalidParameterError as e:
#     220     # When the function is just a wrapper around an estimator, we allow
#     221     # the function to delegate validation to the estimator, but we replace
#     222     # the name of the estimator by the name of the function in the error
#     223     # message to avoid confusion.
#     224     msg = re.sub(
#     225         r"parameter of \w+ must be",
#     226         f"parameter of {func.__qualname__} must be",
#     227         str(e),
#     228     )
#
# File c:\Users\tasne\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\metrics\_classification.py:2634, in precision_score(y_true, y_pred, labels, pos_label, average, sample_weight, zero_division)
#    2464 @validate_params(
#    2465     {
#    2466         "y_true": ["array-like", "sparse matrix"],
#    (...)   2491     zero_division="warn",
#    2492 ):
#    2493     """Compute the precision.
#    2494
#    2495     The precision is the ratio ``tp / (tp + fp)`` where ``tp`` is the number of
#    (...)   2632     array([0.5, 1. , 1. ])
#    2633     """
# -> 2634     p, _, _, _ = precision_recall_fscore_support(
#    2635         y_true,
#    2636         y_pred,
#    2637         labels=labels,
#    2638         pos_label=pos_label,
#    2639         average=average,
#    2640         warn_for=("precision",),
#    2641         sample_weight=sample_weight,
#    2642         zero_division=zero_division,
#    2643     )
#    2644     return p
#
# File c:\Users\tasne\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\_param_validation.py:191, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     189 global_skip_validation = get_config()["skip_parameter_validation"]
#     190 if global_skip_validation:
# --> 191     return func(*args, **kwargs)
#     193 func_sig = signature(func)
#     195 # Map *args/**kwargs to the function signature
#
# File c:\Users\tasne\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\metrics\_classification.py:2100, in precision_recall_fscore_support(y_true, y_pred, beta, labels, pos_label, average, warn_for, sample_weight, zero_division)
#    1929 """Compute precision, recall, F-measure and support for each class.
#    1930
#    1931 The precision is the ratio ``tp / (tp + fp)`` where ``tp`` is the number of
#    (...)   2097  array([2, 2, 2]))
#    2098 """
#    2099 _check_zero_division(zero_division)
# -> 2100 labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#    2102 # Calculate tp_sum, pred_sum, true_sum ###
#    2103 samplewise = average == "samples"
#
# File c:\Users\tasne\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\metrics\_classification.py:1864, in _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#    1861     raise ValueError("average has to be one of " + str(average_options))
#    1863 y_true, y_pred = attach_unique(y_true, y_pred)
# -> 1864 y_type, y_true, y_pred, _ = _check_targets(y_true, y_pred)
#    1865 # Convert to Python primitive type to avoid NumPy type / Python str
#    1866 # comparison. See https://github.com/numpy/numpy/issues/6784
#    1867 present_labels = _tolist(unique_labels(y_true, y_pred))
#
# File c:\Users\tasne\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\metrics\_classification.py:108, in _check_targets(y_true, y_pred, sample_weight)
#      77 """Check that y_true and y_pred belong to the same classification task.
#      78
#      79 This converts multiclass or binary types to a common shape, and raises a
#    (...)    105 sample_weight : array or None
#     106 """
#     107 xp, _ = get_namespace(y_true, y_pred, sample_weight)
# --> 108 check_consistent_length(y_true, y_pred, sample_weight)
#     109 type_true = type_of_target(y_true, input_name="y_true")
#     110 type_pred = type_of_target(y_pred, input_name="y_pred")
#
# File c:\Users\tasne\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:464, in check_consistent_length(*arrays)
#     462 lengths = [_num_samples(X) for X in arrays if X is not None]
#     463 if len(set(lengths)) > 1:
# --> 464     raise ValueError(
#     465         "Found input variables with inconsistent numbers of samples: %r"
#     466         % [int(l) for l in lengths]
#     467     )
#
# ValueError: Found input variables with inconsistent numbers of samples: [320, 80]

# %%
# Visualising the Training set results
 
from matplotlib.colors import ListedColormap
X_Set, Y_Set = x_train, y_train
X1, X2 = np.meshgrid(np.arange(start = X_Set[:,0].min() -1, stop = X_Set[:, 0].max() +1, step = 0.01),
                     np.arange(start = X_Set[:,1].min() -1, stop = X_Set[:, 1].max() +1, step = 0.01))
 
 
plt.contourf(X1,X2, classifier.predict(np.array([X1.ravel(), X2.ravel()]).T).reshape(X1.shape),
             alpha = 0.75, cmap = ListedColormap(('red', 'green')))
 
plt.xlim(X1.min(), X2.max())
plt.ylim(X2.min(), X2.max())
for i, j in enumerate(np.unique(Y_Set)):
    plt.scatter(X_Set[Y_Set == j, 0], X_Set[Y_Set == j,1],
                c = ListedColormap(('yellow', 'blue'))(i), label = j)
plt.title('Logistic Regression ( Training set)')
plt.xlabel('Age')
plt.ylabel('Estimated Salary')
plt.legend()
plt.show()
# Out:
# C:\Users\tasne\AppData\Local\Temp\ipykernel_22612\3432312674.py:15: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   plt.scatter(X_Set[Y_Set == j, 0], X_Set[Y_Set == j,1],
